# %% [markdown]
# #Implementando a leitura de informações dos produtos | Parte (1 de 5)

# %%
codigo = int(input("Digite o codigo do produto: "))
categoria = input("Digite a categoria do produto: ")
nome = input("Digite o nome do produto: ")
descricao = input("Digite uma descrição para o produto: ")
preco = float(input("Digite o preco do produto: "))

# %%
print("------------------------------------------")
print("--------- Informações do produto ---------")
print("------------------------------------------")
print(f"Código: {codigo}")
print(f"Categoria: {categoria}")
print(f"Produto: {nome}")
print(f"Descrição: {descricao}")
print(f"Preço: {preco}")

# %% [markdown]
# #Implementando o cadastro de produtos | Parte (2 de 5)

# %%
"""Trecho de código responsável pelo cadastro de um novo produto"""
def cadastrar_produto(estoque):
  #Obtém as informações do produto atual (Leitura)
  codigo = int(input("Digite o codigo do produto: "))
  categoria = input("Digite a categoria do produto: ")
  nome = input("Digite o nome do produto: ")
  descricao = input("Digite uma descrição para o produto: ")
  preco = float(input("Digite o preco do produto: "))

  #Adiciona produto no estoque (Cadastro)
  produto = {"codigo": codigo, "produto": nome, "info": descricao, "preco": preco}
  if categoria not in estoque:
    estoque[categoria] = []
    estoque[categoria].append(produto)
  else:
    estoque[categoria].append(produto)
  
  #Retorna o estoque atualizado
  return estoque

# %%
#Variável para armazenar os produtos do estoque
estoque = {}

estoque = cadastrar_produto(estoque) #Cadastrar um produto
estoque = cadastrar_produto(estoque) #Cadastrar outro produto
estoque = cadastrar_produto(estoque) #Cadastrar mais um produto

# %%
#Mostrando informações do estoque (Maneira 'ruim', com a leitura amontoada)
print(estoque)

# %%
#Mostrando informações do estoque (Maneira mais organizada)
def mostrar_produto(produto):
  print("------------------------------------------")
  print("--------- Informações do produto ---------")
  print("------------------------------------------")
  print(f"Código: {produto['codigo']}")
  print(f"Produto: {produto['produto']}")
  print(f"Descrição: {produto['info']}")
  print(f"Preço: {produto['preco']}")
  print("")

# %%
#Dados brutos para não precisar digitar
estoque = {"Eletronicos": [{
                              'codigo': 2578,
                              'produto': "Televisão Smart 70'",
                              'info': 'Televisão smart de 70 polegadas, para você assistir a filmes e séries com o maior que a tecnologia pode oferecer. Aproveite!',
                              'preco': 4799.99},
                           {
                              'codigo': 2749,
                              'produto': 'Iphone 14 Pro Max 256GB',
                              'info': 'Iphone 14 Pro Max 256GB de armazenamento interno, acompanha carregador, capinha e película de vidro 3D. Entrega Grátis.',
                              'preco': 9499.99},
                           {
                              'codigo': 1478,
                              'produto': 'Smartphone Samsung Galaxy S23 Ultra',
                              'info': 'Smartphone Galaxy S23 Ultra 512GB de armazenamento interno, 16GB de memória RAM. Câmera de 200MP e Zoom de 10X.',
                              'preco': 6799.99},
                           {
                              'codigo': 3658,
                              'produto': 'Notebook Dell Inspiron',
                              'info': 'Notebook Dell Inspiron: 32GB de RAM, 1TB SSD, 4GB Placa de Vídeo Dedicada, Processador Intel Core i9.',
                              'preco': 12499.99}],
           "Livros":      [{
                              'codigo': 6987,
                              'produto': 'Livro O Senhor dos Anés (Volume único)',
                              'info': 'Livro da obra literária O senhor dos anéis, de J.R.R.Tolkien. Aproveite esta oferta exclusiva!',
                              'preco': 129.0},
                           ]
          }

# %%
def mostra_produtos(estoque):
  for categoria in estoque:
    for produto in estoque[categoria]:
      mostrar_produto(produto)

#Apresenta TODOS os produtos cadastrados
mostra_produtos(estoque)

# %% [markdown]
# #Implementando o menu de interação | Parte (3 de 5)

# %%
while True:
  print("Seja bem-vindo à Ultima Store, sua loja virtual!")
  print("O que você deseja fazer: 1) Cadastrar produto, 0) Sair do programa.")
  opcao = int(input("Digite a opção desejada: "))
  
  #Cadastrar um produto
  if opcao == 1:
    estoque = cadastrar_produto(estoque)
  #Finalizar programa
  elif opcao == 0:
    print("Volte sempre! Agradecemos a preferência!\n")
    break
  #Verifica se a opção passada é inválida
  else:
    print("Opcao inválida!")

# %% [markdown]
# #Implementando a consulta de produtos | Parte (4 de 5)

# %%
while True:
  print("Seja bem-vindo à Ultima Store, sua loja virtual!")
  print("O que você deseja fazer: 1) Cadastrar produto, 2) Mostrar produtos, 0) Sair do programa.")
  opcao = int(input("Digite a opção desejada: "))
  
  #Cadastrar um produto
  if opcao == 1:
    estoque = cadastrar_produto(estoque)
  #Mostrar produtos
  elif opcao == 2:
    mostra_produtos(estoque)
  #Finalizar programa
  elif opcao == 0:
    print("Volte sempre! Agradecemos a preferência!\n")
    break
  #Verifica se a opção passada é inválida
  else:
    print("Opcao inválida!")

# %% [markdown]
# #Implementando o filtro de produtos por preço | Parte (5 de 5)

# %%
#Apresenta os produtos cadastrados com preço inferior ao limite estabelecido
def mostra_produtos_preco(estoque, preco):
  for categoria in estoque:
    for produto in estoque[categoria]:
      if produto["preco"] <= preco:
        mostrar_produto(produto)

# %%
while True:
  print("Seja bem-vindo à Ultima Store, sua loja virtual!")
  print("O que você deseja fazer: 1) Cadastrar produto, 2) Mostrar produtos, 3) Filtrar produtos por preço, 0) Sair do programa.")
  opcao = int(input("Digite a opção desejada: "))
  
  #Cadastrar um produto
  if opcao == 1:
    estoque = cadastrar_produto(estoque)
  
  #Mostrar produtos
  elif opcao == 2:
    mostra_produtos(estoque)
  
  #Mostrar produtos dado um limite de preço
  elif opcao == 3:
    preco_desejado = float(input("Digite o limite máximo de preço a ser buscado: "))
    mostra_produtos_preco(estoque, preco_desejado)
  
  #Finalizar programa
  elif opcao == 0:
    print("Volte sempre! Agradecemos a preferência!\n")
    break
  
  #Verifica se a opção passada é inválida
  else:
    print("Opcao inválida!")

# %% [markdown]
# #Código completo

# %%
"""Trecho de código responsável pelo cadastro de um novo produto"""
def cadastrar_produto(estoque):
  #Obtém as informações do produto atual (Leitura)
  codigo = int(input("Digite o codigo do produto: "))
  categoria = input("Digite a categoria do produto: ")
  nome = input("Digite o nome do produto: ")
  descricao = input("Digite uma descrição para o produto: ")
  preco = float(input("Digite o preco do produto: "))

  #Adiciona um produto no estoque (Cadastro)
  produto = {"codigo": codigo, "produto": nome, "info": descricao, "preco": preco}
  if categoria not in estoque:
    estoque[categoria] = []
    estoque[categoria].append(produto)
  else:
    estoque[categoria].append(produto)
  
  #Retorna o estoque atualizado
  return estoque

# %%
#Mostrando informações do estoque
def mostrar_produto(produto):
  print("------------------------------------------")
  print("--------- Informações do produto ---------")
  print("------------------------------------------")
  print(f"Código: {produto['codigo']}")
  print(f"Produto: {produto['produto']}")
  print(f"Descrição: {produto['info']}")
  print(f"Preço: {produto['preco']}")
  print("")

# %%
#Apresenta TODOS os produtos cadastrados
def mostra_produtos(estoque):
  for categoria in estoque:
    for produto in estoque[categoria]:
      mostrar_produto(produto)

# %%
#Apresenta os produtos cadastrados com preço inferior ao limite estabelecido
def mostra_produtos_preco(estoque, preco):
  for categoria in estoque:
    for produto in estoque[categoria]:
      if produto["preco"] <= preco:
        mostrar_produto(produto)

# %%
#Dados brutos para não precisar digitar
estoque = {"Eletronicos": [{
                              'codigo': 2578,
                              'produto': "Televisão Smart 70'",
                              'info': 'Televisão smart de 70 polegadas, para você assistir a filmes e séries com o maior que a tecnologia pode oferecer. Aproveite!',
                              'preco': 4799.99},
                           {
                              'codigo': 2749,
                              'produto': 'Iphone 14 Pro Max 256GB',
                              'info': 'Iphone 14 Pro Max 256GB de armazenamento interno, acompanha carregador, capinha e película de vidro 3D. Entrega Grátis.',
                              'preco': 9499.99},
                           {
                              'codigo': 1478,
                              'produto': 'Smartphone Samsung Galaxy S23 Ultra',
                              'info': 'Smartphone Galaxy S23 Ultra 512GB de armazenamento interno, 16GB de memória RAM. Câmera de 200MP e Zoom de 10X.',
                              'preco': 6799.99},
                           {
                              'codigo': 3658,
                              'produto': 'Notebook Dell Inspiron',
                              'info': 'Notebook Dell Inspiron: 32GB de RAM, 1TB SSD, 4GB Placa de Vídeo Dedicada, Processador Intel Core i9.',
                              'preco': 12499.99}],
           "Livros":      [{
                              'codigo': 6987,
                              'produto': 'Livro O Senhor dos Anéis (Volume único)',
                              'info': 'Livro da obra literária O senhor dos anéis, de J.R.R.Tolkien. Aproveite esta oferta exclusiva!',
                              'preco': 129.0},
                           ]
          }

# %%
while True:
  print("Seja bem-vindo à Ultima Store, sua loja virtual!")
  print("O que você deseja fazer: 1) Cadastrar produto, 2) Mostrar produtos, 3) Filtrar produtos por preço, 0) Sair do programa.")
  opcao = int(input("Digite a opção desejada: "))
  
  #Cadastrar um produto
  if opcao == 1:
    estoque = cadastrar_produto(estoque)
  
  #Mostrar produtos
  elif opcao == 2:
    mostra_produtos(estoque)
  
  #Mostrar produtos dado um limite de preço
  elif opcao == 3:
    preco_desejado = float(input("Digite o limite máximo de preço a ser buscado: "))
    mostra_produtos_preco(estoque, preco_desejado)
  
  #Finalizar programa
  elif opcao == 0:
    print("Volte sempre! Agradecemos a preferência!\n")
    break
  
  #Verifica se a opção passada é inválida
  else:
    print("Opcao inválida!")
# Out:
# Seja bem-vindo à Ultima Store, sua loja virtual!
# O que você deseja fazer: 1) Cadastrar produto, 2) Mostrar produtos, 3) Filtrar produtos por preço, 4) Sair do programa.
# Digite a opção desejada: 1
# Digite o codigo do produto: 59878
# Digite a categoria do produto: Livros
# Digite o nome do produto: Harry Potter e a Pedra Filosofal
# Digite uma descrição para o produto: Livro capa dura do clássico de J.K.Rolling, Harry Potter e a Pedra Filosofal.
# Digite o preco do produto: 59.90
# Seja bem-vindo à Ultima Store, sua loja virtual!
# O que você deseja fazer: 1) Cadastrar produto, 2) Mostrar produtos, 3) Filtrar produtos por preço, 4) Sair do programa.
# Digite a opção desejada: 2
# ------------------------------------------
# --------- Informações do produto ---------
# ------------------------------------------
# Código: 2578
# Produto: Televisão Smart 70'
# Descrição: Televisão smart de 70 polegadas, para você assistir a filmes e séries com o maior que a tecnologia pode oferecer. Aproveite!
# Preço: 4799.99
#
# ------------------------------------------
# --------- Informações do produto ---------
# ------------------------------------------
# Código: 2749
# Produto: Iphone 14 Pro Max 256GB
# Descrição: Iphone 14 Pro Max 256GB de armazenamento interno, acompanha carregador, capinha e película de vidro 3D. Entrega Grátis.
# Preço: 9499.99
#
# ------------------------------------------
# --------- Informações do produto ---------
# ------------------------------------------
# Código: 1478
# Produto: Smartphone Samsung Galaxy S23 Ultra
# Descrição: Smartphone Galaxy S23 Ultra 512GB de armazenamento interno, 16GB de memória RAM. Câmera de 200MP e Zoom de 10X.
# Preço: 6799.99
#
# ------------------------------------------
# --------- Informações do produto ---------
# ------------------------------------------
# Código: 3658
# Produto: Notebook Dell Inspiron
# Descrição: Notebook Dell Inspiron: 32GB de RAM, 1TB SSD, 4GB Placa de Vídeo Dedicada, Processador Intel Core i9.
# Preço: 12499.99
#
# ------------------------------------------
# --------- Informações do produto ---------
# ------------------------------------------
# Código: 6987
# Produto: Livro O Senhor dos Anés (Volume único)
# Descrição: Livro da obra literária O senhor dos anéis, de J.R.R.Tolkien. Aproveite esta oferta exclusiva!
# Preço: 129.0
#
# ------------------------------------------
# --------- Informações do produto ---------
# ------------------------------------------
# Código: 59878
# Produto: Harry Potter e a Pedra Filosofal
# Descrição: Livro capa dura do clássico de J.K.Rolling, Harry Potter e a Pedra Filosofal.
# Preço: 59.9
#
# Seja bem-vindo à Ultima Store, sua loja virtual!
# O que você deseja fazer: 1) Cadastrar produto, 2) Mostrar produtos, 3) Filtrar produtos por preço, 4) Sair do programa.
# Digite a opção desejada: 3
# Digite o limite máximo de preço a ser buscado: 1000
# ------------------------------------------
# --------- Informações do produto ---------
# ------------------------------------------
# Código: 6987
# Produto: Livro O Senhor dos Anés (Volume único)
# Descrição: Livro da obra literária O senhor dos anéis, de J.R.R.Tolkien. Aproveite esta oferta exclusiva!
# Preço: 129.0
#
# ------------------------------------------
# --------- Informações do produto ---------
# ------------------------------------------
# Código: 59878
# Produto: Harry Potter e a Pedra Filosofal
# Descrição: Livro capa dura do clássico de J.K.Rolling, Harry Potter e a Pedra Filosofal.
# Preço: 59.9
#
# Seja bem-vindo à Ultima Store, sua loja virtual!
# O que você deseja fazer: 1) Cadastrar produto, 2) Mostrar produtos, 3) Filtrar produtos por preço, 4) Sair do programa.
# Digite a opção desejada: 4
# Volte sempre! Agradecemos a preferência!
